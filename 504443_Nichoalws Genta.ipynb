# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt
with rasterio.open("export_demak_fill.TIF") as src :
    data = src.read(1)

# %%
import rasterio
import numpy as np
from rasterio.plot import show
import matplotlib.pyplot as plt
with rasterio.open("export_demak_fill.TIF") as src :
    data = src.read(1)
    show(src.read(), transform=src.transform,cmap="jet")
# plt.imshow(data,cmap="jet")

# %%
with open('nomer.txt') as test:
    teks = test.read().split("\n")[:-1]
    for i in teks:
        if int(i)%2!=0:
            print(int(i)*2)
        else:
            print(i)
# Out:
# 2
# 2
# 6
# 4
# 10
# 6
# 14
# 8
# 18
# 10
